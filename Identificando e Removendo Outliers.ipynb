# %% [markdown]
# # Relatório de Análise VIII

# %% [markdown]
# ## Identificando e Removendo Outliers

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
plt.rc('figure', figsize = (14, 6))

# %%
dados = pd.read_csv('dados/aluguel_residencial.csv', sep = ';')

# %%
dados.boxplot(['Valor'])

# %%
dados[dados['Valor'] >= 500000]
# Out:
#                      Tipo                    Bairro  Quartos  Vagas  Suites  \
# 7629          Apartamento           Barra da Tijuca        1      1       0
# 10636  Casa de Condomínio   Freguesia (Jacarepaguá)        4      2       3
# 12661         Apartamento   Freguesia (Jacarepaguá)        2      2       1
# 13846         Apartamento  Recreio dos Bandeirantes        3      2       1
# 15520         Apartamento                  Botafogo        4      1       1
#
#        Area      Valor  Condominio   IPTU  Valor m2 Tipo Agregado
# 7629     65   600000.0       980.0  120.0   9230.77   Apartamente
# 10636   163   800000.0       900.0    0.0   4907.98          Casa
# 12661   150   550000.0       850.0  150.0   3666.67   Apartamente
# 13846   167  1250000.0      1186.0  320.0   7485.03   Apartamente
# 15520   300  4500000.0      1100.0    0.0  15000.00   Apartamente

# %%
valor = dados['Valor']

# %%
Q1 = valor.quantile(.25)
Q3 = valor.quantile(.75)
IIQ = Q3 - Q1
limite_inferior = Q1 - 1.5 * IIQ
limite_superior = Q3 + 1.5 * IIQ

# %%
selecao = (valor >= limite_inferior) & (valor <= limite_superior)
dados_new = dados[selecao]

# %%
dados_new.boxplot(['Valor'])

# %%
dados.hist(['Valor'])
dados_new.hist(['Valor'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000213D0A1B488>]],
#       dtype=object)

# %% [markdown]
# ## Identificando e Removendo Outliers (Continuação)

# %%
dados.boxplot(['Valor'], by = ['Tipo'])

# %%
grupo_tipo = dados.groupby('Tipo')['Valor']

# %%
type(grupo_tipo)
# Out:
# pandas.core.groupby.generic.SeriesGroupBy

# %%
grupo_tipo.groups
# Out:
# {'Apartamento': Int64Index([    2,     3,     4,     7,     8,     9,    11,    13,    14,
#                 15,
#              ...
#              21813, 21814, 21816, 21817, 21818, 21819, 21821, 21823, 21824,
#              21825],
#             dtype='int64', length=18780),
#  'Casa': Int64Index([    1,    22,    54,    57,    96,   100,   144,   160,   180,
#                238,
#              ...
#              21582, 21606, 21614, 21667, 21672, 21699, 21756, 21781, 21793,
#              21804],
#             dtype='int64', length=965),
#  'Casa de Condomínio': Int64Index([    5,     6,    12,    16,    42,    58,   166,   168,   183,
#                207,
#              ...
#              21709, 21711, 21719, 21752, 21763, 21764, 21782, 21791, 21801,
#              21820],
#             dtype='int64', length=996),
#  'Casa de Vila': Int64Index([   81,   212,   220,   303,   332,   697,   822,   844,   918,
#               1012,
#              ...
#              21184, 21189, 21253, 21325, 21353, 21366, 21588, 21635, 21716,
#              21762],
#             dtype='int64', length=249),
#  'Quitinete': Int64Index([    0,    10,    28,    71,    78,    86,   101,   120,   146,
#                174,
#              ...
#              21384, 21410, 21441, 21656, 21682, 21687, 21728, 21748, 21815,
#              21822],
#             dtype='int64', length=836)}

# %%
Q1 = grupo_tipo.quantile(.25)
Q3 = grupo_tipo.quantile(.75)
IIQ = Q3 - Q1
limite_inferior = Q1 - 1.5 * IIQ
limite_superior = Q3 + 1.5 * IIQ

# %%
Q1
# Out:
# Tipo
# Apartamento           1700.0
# Casa                  1100.0
# Casa de Condomínio    4000.0
# Casa de Vila           750.0
# Quitinete              900.0
# Name: Valor, dtype: float64

# %%
Q3
# Out:
# Tipo
# Apartamento            5000.0
# Casa                   9800.0
# Casa de Condomínio    15250.0
# Casa de Vila           1800.0
# Quitinete              1500.0
# Name: Valor, dtype: float64

# %%
IIQ
# Out:
# Tipo
# Apartamento            3300.0
# Casa                   8700.0
# Casa de Condomínio    11250.0
# Casa de Vila           1050.0
# Quitinete               600.0
# Name: Valor, dtype: float64

# %%
limite_inferior
# Out:
# Tipo
# Apartamento           -3250.0
# Casa                 -11950.0
# Casa de Condomínio   -12875.0
# Casa de Vila           -825.0
# Quitinete                 0.0
# Name: Valor, dtype: float64

# %%
limite_superior
# Out:
# Tipo
# Apartamento            9950.0
# Casa                  22850.0
# Casa de Condomínio    32125.0
# Casa de Vila           3375.0
# Quitinete              2400.0
# Name: Valor, dtype: float64

# %%
limite_superior['Casa']
# Out:
# 22850.0

# %% [markdown]
# <img src='boxplot-imagem.png' width=70%>

# %%
dados_new = pd.DataFrame()
for tipo in grupo_tipo.groups.keys():
    eh_tipo = dados['Tipo'] == tipo
    eh_dentro_limite = (dados['Valor'] >= limite_inferior[tipo]) & (dados['Valor'] <= limite_superior[tipo])
    selecao = eh_tipo & eh_dentro_limite
    dados_selecao = dados[selecao]
    dados_new = pd.contac([dados_new, dados_selecao])
# Out:
# Apartamento
# Casa
# Casa de Condomínio
# Casa de Vila
# Quitinete

# %%
dados_new.boxplot(['Valor'], by = ['Tipo'])

# %%
dados_new.to_csv('dados/aluguel_residencial_sem_outliers.csv', sep=';', index = False)
